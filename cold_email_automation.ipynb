# %%
import smtplib
import pandas as pd
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
import time

sender_email = "pijar2000@gmail.com"
app_password = "xxxxxxxxxxxxxxxxxxxxxxxxxx"  # change to your app password Gmail

# list CSV company
df = pd.read_csv("perusahaan.csv")

for index, row in df.iterrows():
    recipient = row["Email"]
    perusahaan = row["NamaPerusahaan"]

    subject = f"Data Engineer – Open to Opportunities at {perusahaan} - Pijar Hatinurani Merdeka"
    body = f"""Dear {perusahaan} Hiring Team,

My name is Pijar Hatinurani Merdeka. I'm reaching out directly because I'm confident my experience as a Data Engineer would bring real value to {perusahaan}, and I wanted to put myself on your radar ahead of any formal opening.

I'm a Data Engineer with 3+ years of experience building and automating scalable data ecosystems for Telco and enterprise-scale environments. At my current role, I've architected real-time pipelines processing millions to billions of records, including a high-frequency KPI pipeline refreshing every 15 minutes and a multi-source reporting infrastructure unifying on-premise, cloud, and hybrid data sources into a single analytical layer.

My technical stack spans Python, SQL, and Shell scripting for automation, Airflow/Airbyte/Kestra for orchestration, and hands-on cloud expertise across Google Cloud Platform, Databricks, and Microsoft Fabric.

I've attached my CV for reference. I'd welcome the chance to connect and explore how I could contribute to your team, whenever the timing works on your end.

Best regards,
Pijar Hatinurani Merdeka
+628179267154 | pijar2000@gmail.com
github.com/pijar2000 | linkedin.com/in/pijar-hm
"""

    
    msg = MIMEMultipart()
    msg["From"] = sender_email
    msg["To"] = recipient
    msg["Subject"] = subject
    msg.attach(MIMEText(body, "plain"))

    # Your CV
    filename = "Pijar HM CV 9.0.pdf"  # change to your CV file name
    with open(filename, "rb") as f:
        attach = MIMEApplication(f.read(), _subtype="pdf")
        attach.add_header("Content-Disposition", "attachment", filename=filename)
        msg.attach(attach)

    # Kirim email
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
        server.login(sender_email, app_password)
        server.sendmail(sender_email, recipient, msg.as_string())

    print(f"Email + CV SEND TO {recipient}")
    time.sleep(5) 

print("SEND ALL EMAILS!")
# Out:
# Email + CV terkirim ke amagisorakun@gmail.com
# Email + CV terkirim ke amagiclone1@gmail.com
# Semua email percobaan terkirim dengan CV!

# %%
import smtplib
import pandas as pd
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import time

# Data akun pengirim
sender_email = "pijar2000@gmail.com"
app_password = "zcom urfb xfix cyou"  # ganti dengan app password Gmail

# Baca CSV
df = pd.read_csv("perusahaan.csv")

# Loop setiap baris
for index, row in df.iterrows():
    recipient = row["Email"]
    perusahaan = row["NamaPerusahaan"]

    subject = f"Lamaran Data Engineer untuk {perusahaan}"
    body = f"""Halo {perusahaan},

Saya Pijar, Data Engineer dengan pengalaman 3 tahun.
Skill saya meliputi SQL, Bash, Python, dan Linux server operations.

Saya tertarik untuk berkontribusi di {perusahaan}.
Salam,
Pijar
"""

    msg = MIMEMultipart()
    msg["From"] = sender_email
    msg["To"] = recipient
    msg["Subject"] = subject
    msg.attach(MIMEText(body, "plain"))

    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
        server.login(sender_email, app_password)
        server.sendmail(sender_email, recipient, msg.as_string())

    print(f"Email terkirim ke {recipient}")
    time.sleep(5)  # delay 5 detik biar aman dari spam filter

print("Semua email percobaan terkirim!")
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[1], line 47
#      45 # Kirim email
#      46 with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
# ---> 47     server.login(sender_email, app_password)
#      48     server.sendmail(sender_email, recipient, msg.as_string())
#      50 print(f"Email + CV terkirim ke {recipient}")
#
# File c:\Users\pijar2000\AppData\Local\Programs\Python\Python312\Lib\smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File c:\Users\pijar2000\AppData\Local\Programs\Python\Python312\Lib\smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# ...
